# %%
# %cd ..
# %matplotlib inline
# Out:
# D:\Projects\Python\PL-Heuristic

# %%
from analysis.caching import get_cached_results

import pandas as pd

# %% [markdown]
# # Preparation

# %%
data = get_cached_results()

# Prune all heuristic-related columns, as we will not be needing those
data.drop(list(data.filter(regex='heuristic')), axis=1, inplace=True)

data.describe()
# Out:
#        ilp_classroom_utilisation  ilp_instruction_size  ilp_objective  \
# count                7199.000000           7199.000000    7199.000000
# mean                   88.025640             11.666901    6747.593221
# std                    11.950004              4.471715    2425.311201
# min                    60.240964              5.185185    3533.340676
# 25%                    78.313253              8.408259    4417.163803
# 50%                    89.156627             11.428571    5018.009891
# 75%                   100.000000             14.000000    9152.171242
# max                   100.000000             24.360656   10080.377678
#
#        ilp_percentage_instruction  ilp_percentage_self_study  \
# count                 7199.000000                7199.000000
# mean                    65.397746                  34.602254
# std                     21.486019                  21.486019
# min                     18.625000                   1.125000
# 25%                     49.625000                  15.375000
# 50%                     65.500000                  34.500000
# 75%                     84.625000                  50.375000
# max                     98.875000                  81.375000
#
#        ilp_self_study_size  ilp_teacher_utilisation   experiment
# count          7199.000000              7199.000000  7200.000000
# mean             44.584185                67.231039    36.500000
# std              16.177522                17.161373    20.784048
# min               5.000000                39.375000     1.000000
# 25%              31.250000                53.750000    18.750000
# 50%              44.000000                62.500000    36.500000
# 75%              55.055556                83.750000    54.250000
# max              80.000000               100.000000    72.000000

# %%
experiments = pd.read_excel('experiments/experiments.xlsx')
experiments.describe()

# Join with experimental data, so we know the parameter combinations
df = data.join(experiments.set_index('experiment'), on='experiment')

df.describe()
# Out:
#        ilp_classroom_utilisation  ilp_instruction_size  ilp_objective  \
# count                7199.000000           7199.000000    7199.000000
# mean                   88.025640             11.666901    6747.593221
# std                    11.950004              4.471715    2425.311201
# min                    60.240964              5.185185    3533.340676
# 25%                    78.313253              8.408259    4417.163803
# 50%                    89.156627             11.428571    5018.009891
# 75%                   100.000000             14.000000    9152.171242
# max                   100.000000             24.360656   10080.377678
#
#        ilp_percentage_instruction  ilp_percentage_self_study  \
# count                 7199.000000                7199.000000
# mean                    65.397746                  34.602254
# std                     21.486019                  21.486019
# min                     18.625000                   1.125000
# 25%                     49.625000                  15.375000
# 50%                     65.500000                  34.500000
# 75%                     84.625000                  50.375000
# max                     98.875000                  81.375000
#
#        ilp_self_study_size  ilp_teacher_utilisation   experiment      penalty  \
# count          7199.000000              7199.000000  7200.000000  7200.000000
# mean             44.584185                67.231039    36.500000     1.500000
# std              16.177522                17.161373    20.784048     0.500035
# min               5.000000                39.375000     1.000000     1.000000
# 25%              31.250000                53.750000    18.750000     1.000000
# 50%              44.000000                62.500000    36.500000     1.500000
# 75%              55.055556                83.750000    54.250000     2.000000
# max              80.000000               100.000000    72.000000     2.000000
#
#           progress     learners  instruction_classrooms  instruction_size  \
# count  7200.000000  7200.000000             7200.000000       7200.000000
# mean      1.000000  1200.000000               90.000000         24.000000
# std       0.816553   400.027781               43.592017          8.000556
# min       0.000000   800.000000               40.000000         16.000000
# 25%       0.000000   800.000000               70.000000         16.000000
# 50%       1.000000  1200.000000               80.000000         24.000000
# 75%       2.000000  1600.000000              100.000000         32.000000
# max       2.000000  1600.000000              160.000000         32.000000
#
#        self_study_classrooms  self_study_size  num_teachers  first_degree  \
# count            7200.000000           7200.0   7200.000000   7200.000000
# mean                4.500000             80.0    120.000000      0.633333
# std                 1.500104              0.0     40.002778      0.262485
# min                 3.000000             80.0     80.000000      0.400000
# 25%                 3.000000             80.0     80.000000      0.400000
# 50%                 4.500000             80.0    120.000000      0.500000
# 75%                 6.000000             80.0    160.000000      1.000000
# max                 6.000000             80.0    160.000000      1.000000
#
#        second_degree  third_degree
# count     7200.00000   7200.000000
# mean         0.30000      0.066667
# std          0.21604      0.094287
# min          0.00000      0.000000
# 25%          0.00000      0.000000
# 50%          0.40000      0.000000
# 75%          0.50000      0.200000
# max          0.50000      0.200000

# %% [markdown]
# # Analysis
#
# TODO
