# %%
# %cd ..
# %matplotlib inline
# Out:
# D:\Projects\Python\PL-Heuristic

# %%
from analysis.caching import get_cached_results

# %%
df = get_cached_results()
df.describe()
# Out:
#        heuristic_classroom_utilisation  heuristic_instruction_size  \
# count                      7200.000000                 7200.000000
# mean                         94.112125                   11.422859
# std                           6.841519                    4.050563
# min                          66.867470                    5.447368
# 25%                          92.168675                    8.210815
# 50%                          96.385542                   10.923077
# 75%                         100.000000                   13.313725
# max                         100.000000                   23.983871
#
#        heuristic_objective  heuristic_percentage_instruction  \
# count          7200.000000                       7200.000000
# mean           6563.866088                         57.352483
# std            2326.713524                         22.654629
# min            3385.191566                          9.750000
# ...
